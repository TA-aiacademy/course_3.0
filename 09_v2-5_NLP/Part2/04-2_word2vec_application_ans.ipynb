# %% [markdown]
# # the application of word2vec

# %%
from gensim.models import word2vec
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import os
# Out:
# '/datasets/v2-5-nlp/Part2'

# %%
# 上傳資料
# !wget -q https://github.com/TA-aiacademy/course_3.0/releases/download/v2.5_nlp/NLP_part2_4.zip
# !unzip -q NLP_part2_4.zip

# %%
# load word2vec model
model = word2vec.Word2Vec.load('word2vec_model/CBOW')

# %% [markdown]
# ## similarity

# %%
# get most similarity with given words
model.wv.most_similar('KMT')
# Out:
# [('kmt', 0.6586042642593384),
#  ('DPP', 0.6378462314605713),
#  ('國民黨', 0.6356286406517029),
#  ('dpp', 0.573926568031311),
#  ('民進黨', 0.5661280155181885),
#  ('兩黨', 0.5400454998016357),
#  ('政黨', 0.5392645001411438),
#  ('執政', 0.5345873832702637),
#  ('在野黨', 0.5275030136108398),
#  ('執政黨', 0.5125182867050171)]

# %%
# get most similarity with given words's relationship
model.wv.most_similar(positive=['KMT', '綠吱'], negative=['DPP'])
# Out:
# [('紂王', 0.3972617983818054),
#  ('英雄難過', 0.3934878706932068),
#  ('周處', 0.39167141914367676),
#  ('鮮卑', 0.388866662979126),
#  ('火拳', 0.38226616382598877),
#  ('希伯來人', 0.37969887256622314),
#  ('白蓮教', 0.37949398159980774),
#  ('拜火教', 0.37374427914619446),
#  ('包公', 0.37222617864608765),
#  ('明末', 0.37188100814819336)]

# %% [markdown]
# ## clustering

# %%
# create a dictionary: words as key ; count as values
words = {word: vocab.count for word, vocab in model.wv.vocab.items()}

# %%
# sort and select the top 10000 count of words
words = sorted(words.items(), key=lambda x: x[1], reverse=True)
words = words[:10000]
words = np.array(words)[:, 0]
words
# Out:
# array(['人', '八卦', '有沒有', ..., '唯有', '考到', '派遣'], dtype='<U21')

# %%
# extract the word vectors 
vecs = model.wv[words]

# %%
# run clustering algorithm
kmeans = KMeans(n_clusters=50)
cluster = kmeans.fit_predict(vecs)

# %%
# print the result
df = pd.DataFrame([words.tolist(), cluster.tolist()], index=['words', 'no. cluster']).T
df.head(n=5)
# Out:
#   words no. cluster
# 0     人          34
# 1    八卦          44
# 2   有沒有          47
# 3     說          34
# 4     好          47

# %%
df.groupby('no. cluster')

# %%
for k, d in df.groupby('no. cluster'):
    print(k)
    print(d)
# Out:
# 0
#      words no. cluster
# 12      看到           0
# 40      發現           0
# 72       時           0
# 88      突然           0
# 96       跑           0
# ...    ...         ...
# 9766    飛過           0
# 9794   一路上           0
# 9843     繫           0
# 9960    一開           0
# 9963    響起           0
#
# [239 rows x 2 columns]
# 1
#      words no. cluster
# 98      政治           1
# 157     政府           1
# 267     這次           1
# 315     支持           1
# 361      陳           1
# ...    ...         ...
# 9583    巴馬           1
# 9598    幕後           1
# 9842    表態           1
# 9934    連任           1
# 9989    統獨           1
#
# [202 rows x 2 columns]
# 2
#      words no. cluster
# 410     出門           2
# 450     冷氣           2
# 589      度           2
# 626     颱風           2
# 629     天氣           2
# ...    ...         ...
# 9608    風吹           2
# 9727    熱死           2
# 9731    玩水           2
# 9796    炎熱           2
# 9825    雨天           2
#
# [79 rows x 2 columns]
# 3
#         words no. cluster
# 173        影片           3
# 210        電影           3
# 248         拍           3
# 430        電視           3
# 565        故事           3
# ...       ...         ...
# 9827       糞作           3
# 9856       這片           3
# 9862  YOUTUBE           3
# 9881      第二季           3
# 9951       整部           3
#
# [171 rows x 2 columns]
# 4
#      words no. cluster
# 19      朋友           4
# 66      女生           4
# 99      老婆           4
# 112     妹妹           4
# 152      男           4
# ...    ...         ...
# 9765  爸爸媽媽           4
# 9783   左右手           4
# 9839    同居           4
# 9891    單親           4
# 9933    包養           4
#
# [240 rows x 2 columns]
# 5
#      words no. cluster
# 27      今天           5
# 74      時間           5
# 104      完           5
# 159     每天           5
# 188      睡           5
# ...    ...         ...
# 9737    點半           5
# 9790   玩電腦           5
# 9803    晚睡           5
# 9972    入伍           5
# 9980    打呼           5
#
# [217 rows x 2 columns]
# 6
#      words no. cluster
# 14      肥宅           6
# 63      小弟           6
# 149     本魯           6
# 201     小魯           6
# 236     小妹           6
# ...    ...         ...
# 9618    正直           6
# 9661     擼           6
# 9742   小魯妹           6
# 9940    看片           6
# 9955    大給           6
#
# [132 rows x 2 columns]
# 7
#      words no. cluster
# 82       字           7
# 217      寫           7
# 296     英文           7
# 311     意思           7
# 346     內容           7
# ...    ...         ...
# 9667    起源           7
# 9755    難懂           7
# 9771    寫作           7
# 9838    對應           7
# 9908   教科書           7
#
# [153 rows x 2 columns]
# 8
#      words no. cluster
# 283     機車           8
# 285     警察           8
# 295     路上           8
# 467      騎           8
# 656     一台           8
# ...    ...         ...
# 9857    禁行           8
# 9894    車車           8
# 9903    後座           8
# 9914   自行車           8
# 9937    山路           8
#
# [126 rows x 2 columns]
# 9
#      words no. cluster
# 25      最近           9
# 32       題           9
# 38       前           9
# 41      剛剛           9
# 69      安安           9
# ...    ...         ...
# 9744    出爐           9
# 9888    大樹           9
# 9892    一枚           9
# 9954   早上好           9
# 9966    前有           9
#
# [247 rows x 2 columns]
# 10
#      words no. cluster
# 28      中國          10
# 378     臺灣          10
# 417     大陸          10
# 543   中華民國          10
# 588     支那          10
# ...    ...         ...
# 9716   覺青們          10
# 9826    親中          10
# 9874    淪陷          10
# 9904    日治          10
# 9918    鼓吹          10
#
# [159 rows x 2 columns]
# 11
#      words no. cluster
# 80       台          11
# 114     台北          11
# 256     高雄          11
# 284     南部          11
# 571      路          11
# ...    ...         ...
# 9789   外縣市          11
# 9810   嘉義縣          11
# 9868     宮          11
# 9917   大台北          11
# 9925    清水          11
#
# [151 rows x 2 columns]
# 12
#      words no. cluster
# 137     社會          12
# 225     無法          12
# 239     認為          12
# 322     使用          12
# 331     重要          12
# ...    ...         ...
# 9941    何在          12
# 9953    框架          12
# 9970    精準          12
# 9978    講求          12
# 9993    局面          12
#
# [444 rows x 2 columns]
# 13
#      words no. cluster
# 16      my          13
# 140     之內          13
# 147     自刪          13
# 153   仔細閱讀          13
# 286   繁體中文          13
# ...    ...         ...
# 9944    導讀          13
# 9959     祐          13
# 9964     Ｋ          13
# 9971    美艷          13
# 9985     ト          13
#
# [347 rows x 2 columns]
# 14
#      words no. cluster
# 124     地方          14
# 518      蓋          14
# 686     城市          14
# 751     地區          14
# 1213    中心          14
# ...    ...         ...
# 9791    鄰近          14
# 9864    地帶          14
# 9875    高山          14
# 9901    玉山          14
# 9976   夏威夷          14
#
# [153 rows x 2 columns]
# 15
#      words no. cluster
# 323     盒盒          15
# 359      尻          15
# 441      掉          15
# 498      手          15
# 552      懶          15
# ...    ...         ...
# 9830    大包          15
# 9871    月經          15
# 9899    清洗          15
# 9923   白白的          15
# 9962    渾身          15
#
# [288 rows x 2 columns]
# 16
#      words no. cluster
# 52       年          16
# 70       算          16
# 78       月          16
# 129     不到          16
# 174     目前          16
# ...    ...         ...
# 9653    九個          16
# 9858   三十歲          16
# 9860     押          16
# 9919   萬左右          16
# 9948    營收          16
#
# [208 rows x 2 columns]
# 17
#      words no. cluster
# 131     手機          17
# 182     遊戲          17
# 298     網路          17
# 343     電腦          17
# 601     科技          17
# ...    ...         ...
# 9806   任天堂          17
# 9870    性能          17
# 9912    上架          17
# 9945   大富翁          17
# 9947    種花          17
#
# [205 rows x 2 columns]
# 18
#      words no. cluster
# 397     節目          18
# 428      歌          18
# 466      唱          18
# 611     音樂          18
# 770      聖          18
# ...    ...         ...
# 9609   張學友          18
# 9749    作曲          18
# 9812    胡瓜          18
# 9885    聖嫂          18
# 9994    聲勢          18
#
# [170 rows x 2 columns]
# 19
#      words no. cluster
# 229      住          19
# 257      裡          19
# 362     附近          19
# 365      家          19
# 407     外面          19
# ...    ...         ...
# 9372    後門          19
# 9467    開燈          19
# 9505    人住          19
# 9680    警衛          19
# 9758    敲門          19
#
# [136 rows x 2 columns]
# 20
#      words no. cluster
# 553     比賽          20
# 884     大運          20
# 914      世          20
# 950     實力          20
# 1080    一場          20
# ...    ...         ...
# 9820   nba          20
# 9824    喬丹          20
# 9909    第七          20
# 9926     足          20
# 9986    詹皇          20
#
# [117 rows x 2 columns]
# 21
#      words no. cluster
# 86       錢          21
# 278      賺          21
# 344      花          21
# 393     經濟          21
# 489     有錢          21
# ...    ...         ...
# 9542    要繳          21
# 9553    用錢          21
# 9581    遺產          21
# 9627    信用          21
# 9703    多賺          21
#
# [166 rows x 2 columns]
# 22
#         words no. cluster
# 116    iPhone          22
# 264      ASUS          22
# 268      Asus          22
# 307       HTC          22
# 395      Sony          22
# 402   Samsung          22
# 1510   Xiaomi          22
# 2017     OPPO          22
# 2209      LGE          22
# 23
#      words no. cluster
# 36       中          23
# 47       最          23
# 123     變成          23
# 175      屌          23
# 300     代表          23
# ...    ...         ...
# 9850    立志          23
# 9869    會成          23
# 9911    高等          23
# 9949   企業家          23
# 9992     垮          23
#
# [375 rows x 2 columns]
# 24
#      words no. cluster
# 13       吃          24
# 136      麵          24
# 253     好吃          24
# 390     早餐          24
# 469      ㄘ          24
# ...    ...         ...
# 9906     圓          24
# 9922    會點          24
# 9973    大碗          24
# 9982    米糕          24
# 9991   麻辣鍋          24
#
# [268 rows x 2 columns]
# 25
#      words no. cluster
# 176      姆          25
# 370      狗          25
# 418     一隻          25
# 602      隻          25
# 615     貓貓          25
# ...    ...         ...
# 9679    灰色          25
# 9698    養貓          25
# 9754   大自然          25
# 9821    布偶          25
# 9844    企鵝          25
#
# [152 rows x 2 columns]
# 26
#      words no. cluster
# 231      站          26
# 415     捷運          26
# 434      搭          26
# 480      坐          26
# 943     飛機          26
# ...    ...         ...
# 8922   自強號          26
# 9449    莒光          26
# 9718    一站          26
# 9761    票價          26
# 9996    北捷          26
#
# [64 rows x 2 columns]
# 27
#      words no. cluster
# 83       玩          27
# 269      約          27
# 401     活動          27
# 403     吃飯          27
# 439     參加          27
# ...    ...         ...
# 9504    常去          27
# 9527    夜間          27
# 9560    會場          27
# 9614    人到          27
# 9927    展覽          27
#
# [132 rows x 2 columns]
# 28
#      words no. cluster
# 17    from          28
# 21      on          28
# 22      問卦          28
# 23    JPTT          28
# 48      QQ          28
# ...    ...         ...
# 9905    Ps          28
# 9916    慎入          28
# 9968   有多爽          28
# 9975    太神          28
# 9983    噓噓          28
#
# [405 rows x 2 columns]
# 29
#      words no. cluster
# 172     可愛          29
# 222     正妹          29
# 233      長          29
# 412      臉          29
# 423      正          29
# ...    ...         ...
# 9854    太帥          29
# 9865    紳士          29
# 9930    校花          29
# 9961    金色          29
# 9979    肢體          29
#
# [176 rows x 2 columns]
# 30
#      words no. cluster
# 120     禁止          30
# 127     未滿          30
# 130     嚴格          30
# 443     要求          30
# 513     表示          30
# ...    ...         ...
# 9834    軍方          30
# 9876    訴訟          30
# 9889   開放式          30
# 9936    罰則          30
# 9977    董事          30
#
# [309 rows x 2 columns]
# 31
#      words no. cluster
# 57       卻          31
# 193      愛          31
# 221      妳          31
# 224     生活          31
# 241     人生          31
# ...    ...         ...
# 9887    世間          31
# 9900    壓抑          31
# 9974    來臨          31
# 9995    跟隨          31
# 9997    唯有          31
#
# [350 rows x 2 columns]
# 32
#      words no. cluster
# 169      穿          32
# 570     衣服          32
# 904     一件          32
# 1046     T          32
# 1151    內褲          32
# ...    ...         ...
# 9144    暴露          32
# 9210    荷葉          32
# 9299    材質          32
# 9368    全裸          32
# 9795    黑絲          32
#
# [64 rows x 2 columns]
# 33
#      words no. cluster
# 42       買          33
# 62      東西          33
# 190      賣          33
# 303      店          33
# 380     便宜          33
# ...    ...         ...
# 9741    超貴          33
# 9786    採購          33
# 9823    跟進          33
# 9939    用品          33
# 9988    賣完          33
#
# [169 rows x 2 columns]
# 34
#      words no. cluster
# 0        人          34
# 3        說          34
# 37      一直          34
# 45      一堆          34
# 59       小          34
# ...    ...         ...
# 9793    還找          34
# 9799    正經          34
# 9849    下流          34
# 9890   不太敢          34
# 9956    過份          34
#
# [420 rows x 2 columns]
# 35
#      words no. cluster
# 251      喝          35
# 597     飲料          35
# 632      水          35
# 810      泡          35
# 1154    咖啡          35
# 1428     茶          35
# 1660     酒          35
# 1661    奶茶          35
# 1705     菸          35
# 1716    一杯          35
# 1776    牛奶          35
# 1839     冰          35
# 1965     杯          35
# 2179    好喝          35
# 2326    紅茶          35
# 2841   星巴克          35
# 2910    啤酒          35
# 3042    豆漿          35
# 3250    可樂          35
# 3257    義美          35
# 3441   飲料店          35
# 3912    手搖          35
# 4294    鮮奶          35
# 4295    喝完          35
# 4356    喝水          35
# 4409    一罐          35
# 4548   喝咖啡          35
# 5082    化工          35
# 5122    檸檬          35
# 5237    一瓶          35
# 5709    綠茶          35
# 5834    珍奶          35
# 5966    珍珠          35
# 6095    熱水          35
# 6111    喝過          35
# 6238     飲          35
# 6308    果汁          35
# 6898    吸管          35
# 6915   大冰奶          35
# 6944    冰塊          35
# 6950   塑膠袋          35
# 6979    味全          35
# 7096    杯子          35
# 7232    愛喝          35
# 7245    酒精          35
# 7944    難喝          35
# 7947     罐          35
# 8418    蜂蜜          35
# 8606     嵐          35
# 9039    無糖          35
# 9163   林鳳營          35
# 9232    汽水          35
# 9774     瓶          35
# 36
#      words no. cluster
# 9       知道          36
# 10      真的          36
# 11      覺得          36
# 24      好像          36
# 29      比較          36
# ...    ...         ...
# 9832    太常          36
# 9921    超有          36
# 9931   最讓人          36
# 9946    不談          36
# 9967   先不說          36
#
# [368 rows x 2 columns]
# 37
#      words no. cluster
# 128     事情          37
# 184     發生          37
# 281     甲甲          37
# 406     事件          37
# 586     行為          37
# ...    ...         ...
# 9780    痛恨          37
# 9882    犯錯          37
# 9915    腦補          37
# 9938    迴避          37
# 9990    引誘          37
#
# [253 rows x 2 columns]
# 38
#     words no. cluster
# 151    兩則          38
# 39
#      words no. cluster
# 79      工作          39
# 108     公司          39
# 166     老闆          39
# 305     薪水          39
# 382     勞工          39
# ...    ...         ...
# 9610    調薪          39
# 9872    年資          39
# 9943    看護          39
# 9969   責任制          39
# 9999    派遣          39
#
# [156 rows x 2 columns]
# 40
#      words no. cluster
# 291     上面          40
# 310      放          40
# 372      送          40
# 376     照片          40
# 427     處理          40
# ...    ...         ...
# 9847    連絡          40
# 9853    私訊          40
# 9863    評分          40
# 9920   通電話          40
# 9928    三張          40
#
# [232 rows x 2 columns]
# 41
#      words no. cluster
# 77      新聞          41
# 90      發文          41
# 117      版          41
# 122     看板          41
# 138     兩篇          41
# ...    ...         ...
# 9800   第一篇          41
# 9808    亂噓          41
# 9877    刪了          41
# 9950    爆文          41
# 9987   同溫層          41
#
# [193 rows x 2 columns]
# 42
#      words no. cluster
# 121     大學          42
# 164     老師          42
# 194     學校          42
# 199     學生          42
# 320     畢業          42
# ...    ...         ...
# 9730    從國          42
# 9846    生科          42
# 9851    在讀          42
# 9942    財金          42
# 9998    考到          42
#
# [190 rows x 2 columns]
# 43
#      words no. cluster
# 5       台灣          43
# 50      日本          43
# 93      美國          43
# 94      國家          43
# 103     世界          43
# ...    ...         ...
# 9787   原子彈          43
# 9805   烏克蘭          43
# 9867    總理          43
# 9929    緬甸          43
# 9984    台日          43
#
# [172 rows x 2 columns]
# 44
#        words no. cluster
# 1         八卦          44
# 26         請          44
# 31        一下          44
# 33        請問          44
# 61        鄉民          44
# ...      ...         ...
# 9702      版眾          44
# 9829  百思不得其解          44
# 9835      推論          44
# 9861       鞭          44
# 9898    臥虎藏龍          44
#
# [184 rows x 2 columns]
# 45
#      words no. cluster
# 388     身體          45
# 400     醫生          45
# 536     愛滋          45
# 685     醫院          45
# 799     健康          45
# ...    ...         ...
# 9233    咳嗽          45
# 9363    遺傳          45
# 9396    矯正          45
# 9453    復健          45
# 9503   精神科          45
#
# [130 rows x 2 columns]
# 46
#      words no. cluster
# 533      殺          46
# 645     館長          46
# 850      王          46
# 1058    兄弟          46
# 1152    魔法          46
# ...    ...         ...
# 9924    轉生          46
# 9935    武士          46
# 9958    火焰          46
# 9965    人馬          46
# 9981    魯夫          46
#
# [281 rows x 2 columns]
# 47
#      words no. cluster
# 2      有沒有          47
# 4        好          47
# 6       一個          47
# 7        想          47
# 8       現在          47
# ...    ...         ...
# 9895   第一步          47
# 9913   花大錢          47
# 9932   本魯想          47
# 9952    一行          47
# 9957   下輩子          47
#
# [378 rows x 2 columns]
# 48
#       words no. cluster
# 598      停電          48
# 698      發電          48
# 818      反核          48
# 1071     產業          48
# 1408     台電          48
# ...     ...         ...
# 9439     氣體          48
# 9457  PM2.5          48
# 9508     電網          48
# 9580     耗電          48
# 9711     外移          48
#
# [100 rows x 2 columns]
# 49
#         words no. cluster
# 667         神          49
# 793   seafood          49
# 1018       宗教          49
# 1517        信          49
# 1608       師父          49
# ...       ...         ...
# 9097       慈濟          49
# 9246       道教          49
# 9379       傳教          49
# 9665        祂          49
# 9873       慈悲          49
#
# [66 rows x 2 columns]

# %%
# print every cluster of words
data = pd.concat([d[['words']].reset_index(drop=True).rename(columns={'words': k}) for k, d in df.groupby('no. cluster')],
                 axis=1)
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_719/2319527065.py in <module>
#       1 # print every cluster of words
# ----> 2 data = pd.concat([d['words'].reset_index(drop=True).rename(columns={0: k}) for k, d in df.groupby('no. cluster')], axis=1)
#       3 data
#
# /tmp/ipykernel_719/2319527065.py in <listcomp>(.0)
#       1 # print every cluster of words
# ----> 2 data = pd.concat([d['words'].reset_index(drop=True).rename(columns={0: k}) for k, d in df.groupby('no. cluster')], axis=1)
#       3 data
#
# TypeError: rename() got an unexpected keyword argument 'columns'
