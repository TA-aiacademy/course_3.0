# %% [markdown]
# ## $\large{Quiz}$

# %% [markdown]
# 請將左圖中的龍貓完成底下這幾個影像處理，以得到右圖<br>
# 1. 以一半影像長、寬減 1 的 index 作為中心點，將旋轉 45 度角
# 2. 使用鏡像反射補值法
# 3. 將影像放大 2 倍
#
# <img src="https://i.imgur.com/O6g0wsr.jpg" width=400/>  <img src="https://i.imgur.com/XKOOOkJ.jpg" width=400/>

# %%
# upload totoro.png
# !gdown --id 1vIphRAOXbHVwTHsk3vWkX3C2Mk5y2WN0

# %%
path = "totoro.png"

# %%
def load_img(path):
  
  "請寫下你如何作開檔及影像處理"
  
  
  return "請回傳一張影像"

# %%
# upload totoro_ans.png
# !gdown --id 1fiP9GqxKf4cBEq0pOcgj1a0z43-b5GyU

# %%
import cv2
import numpy as np
quiz_img = cv2.imread("totoro_ans.png")[:,:,::-1]
assert np.array_equiv(load_img(path), quiz_img)
