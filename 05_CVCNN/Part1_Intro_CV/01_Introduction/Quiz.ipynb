# %% [markdown]
# ## $\large{Quiz}$

# %% [markdown]
# 請將 Path 中每張影像讀取出來，並將影像路徑和整理成底下的 DataFrame 格式...<br>
# 如下表 my_dataframe 及下圖 my_imageshow

# %%
# upload Simpson.zip
# !gdown "https://drive.google.com/uc?export=download&confirm=no_antivirus&id=1H4-_s3074Il75tlzAtcsU10Yidbs_1wf"
# unzip file
# !unzip -q Simpson.zip

# %%
Path = "./Simpson"

# %% [markdown]
# $\begin{array}{c | c} class & label\\\hline
#  0 & abraham\_grampa\_simpson\\
#  1 & agnes\_skinner\\
#  2 & apu\_nahasapeemapetilon\\
#  3 & bart\_simpson\\
#  4 & carl\_carlson \end{array}$

# %% [markdown]
# ## my_dataframe

# %% [markdown]
# <img src="https://i.imgur.com/sBTAAU5.png" width=350/>

# %% [markdown]
# ## my_imageshow

# %% [markdown]
# <img src="https://i.imgur.com/X9Bmcrw.png" width=600/>
